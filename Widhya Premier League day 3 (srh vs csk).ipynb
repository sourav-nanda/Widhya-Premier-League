# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
matches=pd.read_csv(r'C:\Users\Sourav\Desktop\Notebooks\WPL\Data\matches.csv',parse_dates=['date'])
deliveries=pd.read_csv(r'C:\Users\Sourav\Desktop\Notebooks\WPL\Data\deliveries.csv')
deliveries.drop(['player_dismissed','dismissal_kind','fielder'],inplace=True,axis=1)
deliveries.wide_runs.replace(0,np.nan,inplace=True)

# %%
matches.head()
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune 2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3   4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
srh_csk=matches[((matches.team1=='Sunrisers Hyderabad') | (matches.team2=='Sunrisers Hyderabad')) & ((matches.team1=='Chennai Super Kings') | (matches.team2=='Chennai Super Kings'))]
srh=matches[(matches.team1=='Sunrisers Hyderabad') | (matches.team2=='Sunrisers Hyderabad')]
csk=matches[(matches.team1=='Chennai Super Kings') | (matches.team2=='Chennai Super Kings')]
srh_csk.shape,srh.shape,csk.shape
# Out:
# ((12, 18), (108, 18), (164, 18))

# %%
srh_csk.head()
# Out:
#       id  season       city       date                team1  \
# 413  414    2013    Chennai 2013-04-25  Sunrisers Hyderabad
# 434  435    2013  Hyderabad 2013-05-08  Chennai Super Kings
# 473  474    2014    Sharjah 2014-04-27  Sunrisers Hyderabad
# 506  507    2014     Ranchi 2014-05-22  Chennai Super Kings
# 520  521    2015    Chennai 2015-04-11  Chennai Super Kings
#
#                    team2          toss_winner toss_decision  result  \
# 413  Chennai Super Kings  Sunrisers Hyderabad           bat  normal
# 434  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 473  Chennai Super Kings  Sunrisers Hyderabad           bat  normal
# 506  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 520  Sunrisers Hyderabad  Chennai Super Kings           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 413           0  Chennai Super Kings            0               5
# ...

# %%
srh.head()
# Out:
#     id  season       city       date                  team1  \
# 0    1    2017  Hyderabad 2017-04-05    Sunrisers Hyderabad
# 5    6    2017  Hyderabad 2017-04-09          Gujarat Lions
# 9   10    2017     Mumbai 2017-04-12    Sunrisers Hyderabad
# 13  14    2017    Kolkata 2017-04-15  Kolkata Knight Riders
# 18  19    2017  Hyderabad 2017-04-17    Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 9                Mumbai Indians               Mumbai Indians         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 18              Kings XI Punjab              Kings XI Punjab         field
#
#     result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# ...

# %%
csk.head()
# Out:
#     id  season        city       date                  team1  \
# 60  61    2008  Chandigarh 2008-04-19    Chennai Super Kings
# 66  67    2008     Chennai 2008-04-23    Chennai Super Kings
# 70  71    2008     Chennai 2008-04-26  Kolkata Knight Riders
# 73  74    2008   Bangalore 2008-04-28    Chennai Super Kings
# 78  79    2008     Chennai 2008-05-02    Chennai Super Kings
#
#                           team2            toss_winner toss_decision  result  \
# 60              Kings XI Punjab    Chennai Super Kings           bat  normal
# 66               Mumbai Indians         Mumbai Indians         field  normal
# 70          Chennai Super Kings  Kolkata Knight Riders           bat  normal
# 73  Royal Challengers Bangalore    Chennai Super Kings           bat  normal
# 78             Delhi Daredevils    Chennai Super Kings           bat  normal
#
#     dl_applied               winner  win_by_runs  win_by_wickets  \
# 60           0  Chennai Super Kings           33               0
# ...

# %%
def cat_plot(df,columns,size,plot_type):
    length=len(columns)
    fig,ax=plt.subplots(nrows=length,figsize=size)
    for i in range(length):
        df[columns[i]].value_counts().plot(kind=plot_type,ax=ax[i])
        ax[i].set_title(columns[i])

# %%
cat_plot(srh_csk,['winner','toss_winner','toss_decision'],(12,8),'barh')

# %% [markdown]
# ### Although I am not a cricket viewer and I generally avoid content even remotely related to cricket even I know that CSK isn't performing well in current matches still even though my answer is going to be wrong my analysis suggests that CSK will be the winner so I will go with that option.

# %%
cat_plot(srh,['winner','toss_winner','toss_decision'],(12,8),'barh')

# %%
cat_plot(csk,['winner','toss_winner','toss_decision'],(12,8),'barh')

# %% [markdown]
# ### Highest mean scores in different cities

# %%
fig,ax=plt.subplots(2,2,figsize=(17,13))
matches.groupby('city').mean().sort_values('win_by_runs').win_by_runs.plot.barh(
                                                                                color='orange',
                                                                                title='Matches df',
                                                                                ax=ax[0,0])


srh_csk.groupby('city').mean().sort_values('win_by_runs').win_by_runs.plot.barh(
                                                                                color='g',
                                                                                title='srh_csk df',
                                                                                ax=ax[0,1])


srh.groupby('city').mean().sort_values('win_by_runs').win_by_runs.plot.barh(
                                                                                color='crimson',
                                                                                title='srh df',
                                                                                ax=ax[1,0])


csk.groupby('city').mean().sort_values('win_by_runs').win_by_runs.plot.barh(
                                                                                color='slategray',
                                                                                title='csk df',
                                                                                ax=ax[1,1])

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 1     2  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 2     3  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 3     4  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 4     5  DA Warner    S Dhawan  TS Mills              0        2.0         0
#
# ...

# %%
srh_cskd=deliveries[((deliveries.batting_team=='Sunrisers Hyderabad') | (deliveries.bowling_team=='Sunrisers Hyderabad')) & ((deliveries.batting_team=='Chennai Super Kings') | (deliveries.bowling_team=='Chennai Super Kings'))]
srhd=deliveries[(deliveries.batting_team=='Sunrisers Hyderabad') | (deliveries.bowling_team=='Sunrisers Hyderabad')]
cskd=deliveries[(deliveries.batting_team=='Chennai Super Kings') | (deliveries.bowling_team=='Chennai Super Kings')]

srh_cskd.shape,srhd.shape,cskd.shape
# Out:
# ((2930, 18), (25687, 18), (39318, 18))

# %%
srh_cskd.head()
# Out:
#        match_id  inning         batting_team         bowling_team  over  ball  \
# 97960       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     1
# 97961       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     2
# 97962       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     3
# 97963       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     4
# 97964       414       1  Sunrisers Hyderabad  Chennai Super Kings     1     5
#
#          batsman non_striker     bowler  is_super_over  wide_runs  bye_runs  \
# 97960  Q de Kock    S Dhawan  MM Sharma              0        NaN         0
# 97961  Q de Kock    S Dhawan  MM Sharma              0        NaN         0
# 97962  Q de Kock    S Dhawan  MM Sharma              0        NaN         0
# 97963  GH Vihari    S Dhawan  MM Sharma              0        NaN         0
# 97964  GH Vihari    S Dhawan  MM Sharma              0        NaN         0
#
# ...

# %%
srhd.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 1     2  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 2     3  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 3     4  DA Warner    S Dhawan  TS Mills              0        NaN         0
# 4     5  DA Warner    S Dhawan  TS Mills              0        2.0         0
#
# ...

# %%
cskd.head()
# Out:
#        match_id  inning         batting_team     bowling_team  over  ball  \
# 14087        61       1  Chennai Super Kings  Kings XI Punjab     1     1
# 14088        61       1  Chennai Super Kings  Kings XI Punjab     1     2
# 14089        61       1  Chennai Super Kings  Kings XI Punjab     1     3
# 14090        61       1  Chennai Super Kings  Kings XI Punjab     1     4
# 14091        61       1  Chennai Super Kings  Kings XI Punjab     1     5
#
#          batsman non_striker bowler  is_super_over  wide_runs  bye_runs  \
# 14087   PA Patel   ML Hayden  B Lee              0        NaN         0
# 14088   PA Patel   ML Hayden  B Lee              0        NaN         0
# 14089   PA Patel   ML Hayden  B Lee              0        NaN         0
# 14090  ML Hayden    PA Patel  B Lee              0        NaN         0
# 14091  ML Hayden    PA Patel  B Lee              0        NaN         0
#
#        legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# ### I misunderstood the 2nd question initially so i was summing the wide runs instead of checking its frequency but while calculating the count the function was counting even the 0 instances and custom function doesn't work as it for some reason so I just replaced all the 0s in wide_runs column with NaNs at the beginning of the notebook

# %%
'''def counter(): 
    x=0
    if x>0:
        x+=1
    else:
        pass
    return x'''


srh_cskdwide=srh_cskd.pivot_table(index='match_id',values='wide_runs',aggfunc='count')
srh_cskdwide
# Out:
#           wide_runs
# match_id
# 414               7
# 435               9
# 474               3
# 507               3
# 521               8
# 551               7
# 7913              6
# 7939             11
# 7950             12
# 7953              9
# 11324             6
# 11332             5

# %%
#Just to confirm whether it's actually the frequency of wide runs or am i doing something wrong
srh_cskd.pivot_table(index='match_id',values='wide_runs',aggfunc='count').iloc[0,0],srh_cskd[srh_cskd.match_id==414].wide_runs.count()

#Works fine
# Out:
# (7, 7)

# %%
srhd_wide=srhd.pivot_table(index='match_id',values='wide_runs',aggfunc='count')
srhd_wide
# Out:
#           wide_runs
# match_id
# 1                 8
# 6                 3
# 10                6
# 14               10
# 19               10
# ...             ...
# 11336             6
# 11339            16
# 11342             3
# 11345             9
# 11413            10
#
# [108 rows x 1 columns]

# %%
cskd_wide=cskd.pivot_table(index='match_id',values='wide_runs',aggfunc='count')
cskd_wide
# Out:
#           wide_runs
# match_id
# 61                7
# 67               11
# 71                8
# 74                9
# 79                6
# ...             ...
# 11341             4
# 11346             6
# 11412             3
# 11414             4
# 11415             7
#
# [164 rows x 1 columns]

# %%
deliverieswide=deliveries.pivot_table(index='match_id',values='wide_runs',aggfunc='count')
deliverieswide
# Out:
#           wide_runs
# match_id
# 1                 8
# 2                 8
# 3                 9
# 4                13
# 5                 8
# ...             ...
# 11347             9
# 11412             3
# 11413            10
# 11414             4
# 11415             7
#
# [756 rows x 1 columns]

# %%
print('Average wide balls frequency derived from head to head matches as well as matches with other teams is:\n',(cskd_wide.mean()+srhd_wide.mean()+srh_cskdwide.mean())/3,'\n\n')

print('Average wide balls deviation from the mean derived from head to head matches as well as matches with other teams is:\n',(cskd_wide.std()+srhd_wide.std()+srh_cskdwide.std())/3,'\n\n')

print('Average wide balls frequency derived from all the matches alongwith standard deviation:\n','Mean:',deliverieswide.mean(),'Standard deviation:',deliverieswide.std())
# Out:
# Average wide balls frequency derived from head to head matches as well as matches with other teams is:
#  wide_runs    6.889642
# dtype: float64
#
#
# Average wide balls deviation from the mean derived from head to head matches as well as matches with other teams is:
#  wide_runs    2.934043
# dtype: float64
#
#
# Average wide balls frequency derived from all the matches alongwith standard deviation:
#  Mean: wide_runs    7.149471
# dtype: float64 Standard deviation: wide_runs    3.127767
# dtype: float64

# %% [markdown]
# ### From the above analysis we can conclude that there can be more than 6 wide balls in the match

# %%
for _ in deliveries.batsman:
    if _.endswith('Warner'):
        print(_)
        break
# Out:
# DA Warner

# %%
dawarner_scores=deliveries[deliveries.batsman=='DA Warner'].groupby('match_id').sum().batsman_runs
dawarner_scores
# Out:
# match_id
# 1        14
# 6        76
# 10       49
# 14       26
# 19       70
#          ..
# 11324    51
# 11329    70
# 11332    59
# 11336    40
# 11339    91
# Name: batsman_runs, Length: 126, dtype: int64

# %%
dawarner_scores.mean(),dawarner_scores.median(),dawarner_scores.std()
# Out:
# (37.62698412698413, 33.0, 30.513664906591384)

# %% [markdown]
# #### It seems there are a lot of outliers in the runs which leads to a std of 30+ although it is expected from a human let's try a better method for a more accurate prediction

# %%
plt.figure(figsize=(16,5))
sns.violinplot(dawarner_scores.value_counts())

# %% [markdown]
# #### It' s still uncertain as the data indicates that he's more likely to score less and although that's more frequent it still can be considered as an outlier

# %%
csk_wickets=csk.win_by_wickets
csk_wickets.mean(),csk_wickets.std()
# Out:
# (3.152439024390244, 3.3056829894794806)

# %%
csk_wickets.value_counts().plot.pie(figsize=(12,9))

# %% [markdown]
# ### As winning by 0 wickets is not possible and it is only there in the column instead of null values so we are better of going with something close to the mean value

# %%
fig=plt.figure(figsize=(16,8))
fig.add_subplot(221)
srhd_runs=srhd.groupby('match_id').sum().total_runs
cskd_runs=cskd.groupby('match_id').sum().total_runs
sns.violinplot(srhd_runs,
               split=True,
               width=0.8)

plt.title('SRH')

fig.add_subplot(222)
sns.violinplot(cskd_runs,
               split=True,
               width=0.8)
plt.title('CSK')
# Out:
# Text(0.5, 1.0, 'CSK')

# %%
(srhd_runs.mean()+cskd_runs.mean())/2
# Out:
# 313.5666214995483

# %% [markdown]
# ### The overall runs of both the teams are spread over quite a lot but we can safely assume that the total score will be between 310-330
